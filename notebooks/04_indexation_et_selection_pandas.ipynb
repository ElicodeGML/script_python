# %%
# ============================================# 1. IMPORT ET CHARGEMENT DES DONNÉES# ============================================from google.colab import filesimport pandas as pd# Télécharger le fichier CSVuploaded = files.upload()file_name = Noneif uploaded:    for fn in uploaded.keys():        print(f'Fichier "{fn}" téléchargé.')        file_name = fnelse:    print("Aucun fichier n'a été téléchargé. Veuillez le télécharger manuellement ou exécuter cette cellule à nouveau.")# Charger le fichier CSV dans un DataFramedf = pd.read_csv('data.csv')print(f"✓ DataFrame chargé ! Dimensions: {df.shape}")print(f"Colonnes disponibles: {df.columns.tolist()}")

# %%
# ============================================# 2. SÉLECTION DE COLONNES (Deux syntaxes)# ============================================# Syntaxe 1: Utiliser les crochets []print("Syntaxe 1 - df['colonne'].head():")df["email"].head()

# %%
# Syntaxe 2: Utiliser la notation pointée df.colonneprint("Syntaxe 2 - df.colonne.head():")df.email.head()

# %%
# ============================================# 3. VÉRIFICATION DES TYPES# ============================================# Type du DataFrameprint("Type du DataFrame:")type(df)
