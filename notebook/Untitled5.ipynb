# %%
import pandas as pd
import numpy as np

# Données fictives pour un enfant
# Poids (grammes), Texture (1=lisse, 10=rugueux), Couleur (1=rouge, 10=jaune)
data = {
    'poids': [150, 130, 120, 180, 50, 60, 70, 160, 155],
        'texture': [1, 2, 1, 2, 8, 9, 7, 5, 6],
            'couleur': [2, 1, 2, 1, 9, 10, 8, 5, 4],
                'fruit': ['Pomme', 'Pomme', 'Pomme', 'Pomme', 'Citron', 'Citron', 'Citron', 'Orange', 'Orange']
                }

                df = pd.DataFrame(data)
