# %%
import pandas as pd
import numpy as np

# Données fictives pour un enfant
# On ajoute la Banane et le Raisin + le critère "Forme"
data = {
    'poids': [150, 50, 160, 120, 5],
    'texture': [1, 9, 5, 2, 1],
    'couleur': [2, 10, 5, 10, 3],
    'forme': [1, 2, 2, 10, 1], # 1=rond, 10=long
    'fruit': ['Pomme', 'Citron', 'Orange', 'Banane', 'Raisin']
}
df = pd.DataFrame(data)

# Si tu donnes à l'IA : Poids=110, Texture=2, Couleur=9, Forme=9
# Elle va voir "Forme=9" et "Couleur=10" -> Elle dira "Banane" !


df = pd.DataFrame(data)

# %%
# On teste avec un fruit de 140g, texture lisse (1), couleur rouge (2)
mystere = [[140, 1, 2, 5]]
prediction = model.predict(mystere)
nom_du_fruit = le.inverse_transform(prediction)

print(f"L'IA dit que c'est une : {nom_du_fruit[0]} !")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17259/1601224328.py in <cell line: 0>()
#       1 # On teste avec un fruit de 140g, texture lisse (1), couleur rouge (2)
#       2 mystere = [[140, 1, 2, 5]]
# ----> 3 prediction = model.predict(mystere)
#       4 nom_du_fruit = le.inverse_transform(prediction)
#       5
#
# /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     902             The predicted classes.
#     903         """
# --> 904         proba = self.predict_proba(X)
#     905
#     906         if self.n_outputs_ == 1:
#
# ...
