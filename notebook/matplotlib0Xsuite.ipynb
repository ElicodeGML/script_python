# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y= iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a  {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a  3 classes

# %%
plt.scatter(x[:,0],x[:,1],c=y, alpha=0.5, s=x[:, 2]*100)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.show()

# %%
# %matyplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x[:,0],x[:,1],x[:,2],c=y, alpha=0.5)
ax.view_init(10, 10, 10)
plt.show()

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %%
from matplotlib import cm
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')
plt.show()

# %%
plt.hist(x[:,0], bins=25, alpha=0.5)
plt.hist(x[:,1], bins=25, alpha=0.5)
plt.show()

# %%
plt.hist2d(x[:,0], x[:,1], bins=50, alpha=0.5)
plt.colorbar()
plt.show()

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)
X = np.linspace(0, 5, 50)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %%
plt.contourf(X, Y, Z, 50)
plt.colorbar()
plt.show()

# %%
plt.imshow(np.corrcoef(x.T), cmap='plasma')
plt.xticks(range(x.shape[1]), iris.feature_names)
plt.yticks(range(x.shape[1]), iris.feature_names)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.imshow(Z, cmap='plasma')
plt.colorbar()
plt.show()

# %%
dataset = {f'experience{i}': np.random.randn(100) for i in range(4)}

# %%
# @title
def graphique(iris):
  n = len(iris)
  plt.figure(figsize=(12, 8))

  for k, i in zip (iris.keys(), range(1, n+1)):
    plt.subplot(n, 1, i)
    plt.plot(iris[k])
    plt.title(k)

plt.show()

# %%
graphique(dataset)

# %%
plt.hexbin(X, Y)
plt.colorbar()
plt.show()
