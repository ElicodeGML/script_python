# %%
# @title
from google.colab import files

uploaded = files.upload()

file_name = None
if uploaded:
  for fn in uploaded.keys():
    print(f'Fichier "{fn}" téléchargé.')
    file_name = fn
else:
  print("Aucun fichier n'a été téléchargé. Veuillez le télécharger manuellement ou exécuter cette cellule à nouveau.")
  # @title
import pandas as pd
df = pd.read_csv('data.csv')
# Out:
#      <input type="file" id="files-16388b84-9ebf-4611-80cd-bafcd22dcbc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16388b84-9ebf-4611-80cd-bafcd22dcbc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# @title
df.price_paid = df.price_paid.apply(lambda x: x.replace('$', ''))
df.price_paid = df.price_paid.astype(float)

# %%
df['price_paid'].mean().round(2)
# Out:
# np.float64(6.46)

# %%
df['price_paid'].sum()
# Out:
# np.float64(6461.93)

# %%
df['price_paid'].min()

# %%
df['price_paid'].max()

# %%
df['price_paid'].unique()

# %%
df['country'].value_counts()

# %%
df['gender'].value_counts(normalize=True).round(2)

# %%
df.groupby('gender')['price_paid'].mean().round(2)
# Out:
# gender
# Female    6.42
# Male      6.47
# Name: price_paid, dtype: float64

# %%
df.groupby(['gender', 'country'])['price_paid'].mean().round(2)
# Out:
# gender  country
# Female  Canada           6.42
#         France           6.35
#         Morocco          7.02
#         United States    6.44
# Male    Canada           6.12
#         France           6.50
#         Morocco          6.15
#         United States    6.67
# Name: price_paid, dtype: float64
