# %%
# @title
from google.colab import files

uploaded = files.upload()

file_name = None
if uploaded:
  for fn in uploaded.keys():
    print(f'Fichier "{fn}" téléchargé.')
    file_name = fn
else:
  print("Aucun fichier n'a été téléchargé. Veuillez le télécharger manuellement ou exécuter cette cellule à nouveau.")
  # @title
import pandas as pd
df = pd.read_csv('data.csv')
# Out:
#      <input type="file" id="files-26274f52-c9a4-4f59-9a41-ca0b8f476db9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26274f52-c9a4-4f59-9a41-ca0b8f476db9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df["email"].head()
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %%
df.email.head()
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.email)
# Out:
# pandas.core.series.Series

# %%
df[10:13]
# Out:
#     id        date first_name  last_name                       email  gender  \
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
#
#         ip_address        country price_paid   tax
# 10   201.76.240.51         Canada      $5.71   NaN
# 11  222.60.138.222  United States      $3.15  20.0
# 12   24.25.198.252         Canada      $5.30  20.0

# %%
df.loc[10:13]
# Out:
#     id        date first_name  last_name                       email  gender  \
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
#
#         ip_address        country price_paid   tax
# 10   201.76.240.51         Canada      $5.71   NaN
# 11  222.60.138.222  United States      $3.15  20.0
# 12   24.25.198.252         Canada      $5.30  20.0
# 13    18.203.61.94         France      $5.97  20.0

# %%
df_email = df.set_index("email")
df_email.loc['cvassied@unblog.fr'].values.tolist()
# Out:
# [np.int64(14),
#  '03/24/2021',
#  'Cull',
#  'Vassie',
#  nan,
#  '18.203.61.94',
#  'France',
#  '$5.97',
#  np.float64(20.0)]

# %%
df_email.loc[['cvassied@unblog.fr', 'eallawayg@ebay.co.uk']]
# Out:
#                       id        date first_name last_name  gender  \
# email
# cvassied@unblog.fr    14  03/24/2021       Cull    Vassie     NaN
# eallawayg@ebay.co.uk  17  03/27/2021        Eve   Allaway  Female
#
#                           ip_address        country price_paid   tax
# email
# cvassied@unblog.fr      18.203.61.94         France      $5.97  20.0
# eallawayg@ebay.co.uk  184.107.59.156  United States      $6.44  20.0
