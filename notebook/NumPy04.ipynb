# %%
import numpy as np

# %%
# @title
np.random.seed(0)
A = np.random.randint(0, 10, [2, 3])
A
# Out:
# array([[5, 0, 3],
#        [3, 7, 9]])

# %%
a = A.sum(axis=0)
b = A.sum(axis=1)
a, b
# Out:
# (array([ 8,  7, 12]), array([ 8, 19]))

# %%
A.var()
# Out:
# np.float64(8.583333333333334)

# %%
np.corrcoef(A)
# Out:
# array([[ 1.        , -0.56362148],
#        [-0.56362148,  1.        ]])

# %%
np.corrcoef(A)[0, 1]
# Out:
# np.float64(-0.56)

# %%
values, counts = np.unique(A, return_counts=True)

# %%
values[counts.argsort()], counts[counts.argsort()]
# Out:
# (array([0, 5, 7, 9, 3]), array([1, 1, 1, 1, 2]))

# %%
np.nancumsum(A, axis=1)
# Out:
# array([[ 5,  5,  8],
#        [ 3, 10, 19]])

# %%
np.isnan(A).sum()
# Out:
# np.int64(0)

# %%
np.isnan(A).sum()/A.size
# Out:
# np.float64(0.0)

# %%
image = np.array([[0, 2, 18, 1, 0],
                  [1, 15, 20, 14, 2],
                  [19, 3, 1, 17, 1],
                  [2, 16, 18, 15, 0],
                  [0, 1, 19, 2, 1]])

# %%
image.mean()
# Out:
# np.float64(7.52)

# %%
image[image > 10]
# Out:
# array([18, 15, 20, 14, 19, 17, 16, 18, 15, 19])

# %%
image[image < 10] = 0
image
# Out:
# array([[ 0,  0, 18,  0,  0],
#        [ 0, 15, 20, 14,  0],
#        [19,  0,  0, 17,  0],
#        [ 0, 16, 18, 15,  0],
#        [ 0,  0, 19,  0,  0]])
